# %%
import kchannel

# %%
coor = "/home/clam/test/nvt.gro"
traj = "/home/clam/test/fixed_c.xtc"
df = kchannel.run(coor, traj, distance=True)
# Out:
# At frame 187, double occupancy in S1
# At frame 492, double occupancy in S1
# At frame 3319, double occupancy in S4
# At frame 3327, double occupancy in S4
# At frame 3373, double occupancy in S4
# At frame 3374, double occupancy in S4
# At frame 3452, double occupancy in S1
# At frame 3483, double occupancy in S1
# At frame 3495, double occupancy in S1
# At frame 3732, double occupancy in S4
# At frame 3784, double occupancy in S4
# At frame 3829, double occupancy in S4
# At frame 3845, double occupancy in S4
# At frame 3869, double occupancy in S4
# At frame 3879, double occupancy in S4
# At frame 3909, double occupancy in S1
# At frame 3988, double occupancy in S1
# At frame 4069, double occupancy in S1
# At frame 4287, double occupancy in S4
# At frame 4457, double occupancy in S1
# At frame 4466, double occupancy in S1
# At frame 4469, double occupancy in S1
# At frame 4629, double occupancy in S1
# At frame 4748, double occupancy in S4
# At frame 4749, double occupancy in S4
# ...

# %%
df
# Out:
#       occupancy j_k j_w flip_0 flip_1 flip_2 flip_3 flip_4   CA_44_0  \
# 0        K0KKWW   0  -1      0      0      0      0      0  7.665094
# 1        K0KKWW   0   4      0      0      0      0      0  7.408526
# 2        K0KKWW   0  -3      0      0      0      0      0  7.707372
# 3        K0KKWW   0  -3      0      0      0      0      0  7.597925
# 4        K0KKWW   0   4      0      0      0      0      0  7.702521
# ...         ...  ..  ..    ...    ...    ...    ...    ...       ...
# 12496    KWKWKW   0   2      0      0      0      0      0  7.769977
# 12497    KWKWKW   0  -2      0      0      0      0      0  7.656283
# 12498    KWKWKW   0   0      0      0      0      0      0  7.596065
# 12499    KWKWKW   0  -2      0      0      0      0      0  7.315307
# 12500    KWKWKW   0   0      0      0      0      0      0  8.024501
#
#         CA_44_1  ...    O_44_0    O_44_1    O_43_0    O_43_1    O_42_0  \
# ...

# %%
df['occupancy'].to_numpy()
# Out:
# array(['K0KKWW', 'K0KKWW', 'K0KKWW', ..., 'KWKWKW', 'KWKWKW', 'KWKWKW'],
#       dtype=object)
